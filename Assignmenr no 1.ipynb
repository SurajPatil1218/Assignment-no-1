# %%
## Task No 1

n = int(input("Entre the first no : "))
x = int(input("Entre the second no :"))
print("Addition :",(n + x))
print("Subtraction :",(n - x))
print("Multiplication :",(n * x))
print("Division :",(n / x))
# Out:
# Entre the first no :  5
# Entre the second no : 2
# Addition : 7
# Subtraction : 3
# Multiplication : 10
# Division : 2.5

# %%
## Task No 2 

x = input("Entre the first name :")
c = input("Entre the last name : ")
print("Hello,",x,c,"Welcome to python programming.")
# Out:
# Entre the first name : John
# Entre the last name :  Doe
# Hello, John Doe Welcome to python programming.
